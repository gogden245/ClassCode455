# %%
def decipher_caesar_cipher(encoded_message, key):
    deciphered_message = ""
    for char in encoded_message:
        if char.isalpha():
            # Determine whether the character is uppercase or lowercase
            if char.isupper():
                # Shift the character back by the key value
                shifted_char = chr((ord(char) - key - 65) % 26 + 65)
            else:
                shifted_char = chr((ord(char) - key - 97) % 26 + 97)
            deciphered_message += shifted_char
        else:
            # If the character is not a letter, keep it unchanged
            deciphered_message += char
    return deciphered_message

# Example usage:
encoded_message = """
Puneyrf Uverf naq gur Qevax gung Jbjrq n Angvba- Avargrragu-praghel Nzrevpn jnf sbe znal n ynaq bs cbffvovyvgl, jurer n ynq bs uhzoyr bevtva guebhtu jvgf, vavgvngvir naq n yvggyr tbbq yhpx zvtug npuvrir gur cvaanpyr bs jrnygu naq vasyhrapr. Ubengvb Nytre pryroengrq gurve entf-gb-evpurf syvtugf va qbmraf bs abiryf.

Puneyrf Uverf' cerpbpvgl znl vaqrrq unir vzcerffrq gur abiryvfg. Nsgre yrnivat ubzr ng ntr 12, Uverf pbzcyrgrq uvf qeht fgber ncceragvprfuvc sbhe lrnef yngre. Ol ntr 21 ur unq fnirq rabhtu zbarl gb bcra uvf bja cuneznpl va Cuvynqrycuvn. Svir lrnef yngre ur fbyq gung fgber gb sbhaq jung jbhyq orpbzr n cebfcrebhf ohfvarff jubyrfnyvat qehtf naq obgnavpny cebqhpgf.

Jura bayl 25, Uverf vagebqhprq gb gur jbeyq n qevax ur qvfpbirerq naq cnvafgnxvatyl cresrpgrq. Uverf' Ebbg Orre jbhyq orpbzr n angvbany snibevgr. Ng ntr 39 ur vapbecbengrq gur Puneyrf R. Uverf Pb., sbe znal lrnef gur jbeyq'f ynetrfg ebbg orre znxre.

Gur lbhat qehttvfg'f pnerre cngu gbbx n sngrshy ghea, juvyr ba n snez inpngvba jvgu uvf erprag oevqr Pynen Xngr va 1875. Gurve ubfgrff freirq gur cevz lbhat pbhcyr n grn oerjrq sebz ebbgf, onex naq oreevrf fur unq sbentrq. Fzvggra jvgu gur qevax'f synibe, Uverf erghearq gb Cuvynqrycuvn jvgu vgf erpvcr va uvf cbpxrg.

Ersbezhyngrq, ersvarq naq eranzrq, gur pbapbpgvba gung rzretrq sebz Uverf' fbqn sbhagnva jnf na rneyl pbairavrapr sbbq. Ab ybatre jbhyq ubhfrjvirf unir gb tngure naq cebprff n fyrj bs vaterqvragf gb cercner n erserfuvat orirentr sbe gurve snzvyvrf. N 25-prag obk bs Uverf rkgenpg, jura pbzovarq jvgu jngre, fhtne naq lrnfg, lvryqrq svir tnyybaf bs rssreirfprag ebbg orre.

Uverf vagebqhprq gur qevax ng gur 1876 Pragraavny Rkuvovgvba naq gragngviryl ortna gb cebzbgr vg jvgu bar pbyhza ol bar vapu arjfcncre nqf.

Zl obbx erpbhagf Uverf' riragshy wbhearl ntnvafg gur onpxqebc bs uvf cynpr naq gvzrf, Nzrevpn bs gur yngr 19gu naq rneyl 20gu praghevrf. Uvf yvsr naq pnerre jrer varkbenoyl funcrq ol gur qlanzvp fbpvny naq rpbabzvp sbeprf gung guehfg gur angvba vagb gur arj praghel. Gurfr vapyhqrq gur ebhtu-urja pncvgnyvfz bs gur tvyqrq ntr, gur fhetr bs vatrahvgl gung fcnjarq na ren bs vairagvba, gur ribyhgvba bs gur pbeare qehtfgber, gur evfr bs nqiregvfvat va perngvat znff znexrgf, naq gur rzretvat grzcrenapr zbirzrag.
"""
key = 13
deciphered_message = decipher_caesar_cipher(encoded_message, key)
print("Deciphered message:", deciphered_message)
# Out:
# Deciphered message:
# Charles Hires and the Drink that Wowed a Nation- Nineteenth-century America was for many a land of possibility, where a lad of humble origin through wits, initiative and a little good luck might achieve the pinnacle of wealth and influence. Horatio Alger celebrated their rags-to-riches flights in dozens of novels.
#
# Charles Hires' precocity may indeed have impressed the novelist. After leaving home at age 12, Hires completed his drug store apprenticeship four years later. By age 21 he had saved enough money to open his own pharmacy in Philadelphia. Five years later he sold that store to found what would become a prosperous business wholesaling drugs and botanical products.
#
# When only 25, Hires introduced to the world a drink he discovered and painstakingly perfected. Hires' Root Beer would become a national favorite. At age 39 he incorporated the Charles E. Hires Co., for many years the world's largest root beer maker.
#
# ...

# %%
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.backends import default_backend
import binascii

def decrypt_chacha20(encrypted_file_path, key, nonce):
    with open(encrypted_file_path, 'rb') as file:
        ciphertext = file.read()

    backend = default_backend()
    cipher = Cipher(algorithms.ChaCha20(key, nonce), mode=None, backend=backend)
    decryptor = cipher.decryptor()
    decrypted_data = decryptor.update(ciphertext) + decryptor.finalize()

    return decrypted_data

# Convert nonce to bytes
nonce_bytes = bytes("abcdefgh", "ascii")

# Key (assuming already obtained from memory)
key_bytes = b'\x00' * 32  # Placeholder key

# Provide the path to the encrypted file
encrypted_file_path = "path/to/encrypted/file"

# Decrypt the file
decrypted_data = decrypt_chacha20(encrypted_file_path, key_bytes, nonce_bytes)

# Save or process the decrypted data as needed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 26
#      23 encrypted_file_path = "path/to/encrypted/file"
#      25 # Decrypt the file
# ---> 26 decrypted_data = decrypt_chacha20(encrypted_file_path, key_bytes, nonce_bytes)
#      28 # Save or process the decrypted data as needed
#
# Cell In[1], line 6, in decrypt_chacha20(encrypted_file_path, key, nonce)
#       5 def decrypt_chacha20(encrypted_file_path, key, nonce):
# ----> 6     with open(encrypted_file_path, 'rb') as file:
#       7         ciphertext = file.read()
#       9     backend = default_backend()
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
# ...
